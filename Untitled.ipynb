# %%
#Leitura de Dados (em Excel(Planilha), Texto ou csv(Texto Com Separação))

import pandas as pd

df = pd.read_csv("pibit221.csv")
#df = pd.read_csv("pokemon_data.csv")
#print(df.head())

#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx.head(9))

#df = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(df)
# Out:
#                    Hora                            Nome completo  \
# 0       8/11/2022 16:51                        Cristian Cechinel
# 1       8/11/2022 16:50                        Cristian Cechinel
# 2       1/11/2022 23:48      José Inácio Mota Nazario (22103674)
# 3       1/11/2022 23:48      José Inácio Mota Nazario (22103674)
# 4       1/11/2022 23:48      José Inácio Mota Nazario (22103674)
# 5      30/10/2022 14:55   Pedro Otávio Furtado Duarte (22103861)
# 6      27/10/2022 15:38        Letícia Torcheto Ramos (22103677)
# 7      25/10/2022 23:12   Luís Felipe Mattos da Silva (22103676)
# 8      25/10/2022 23:12   Luís Felipe Mattos da Silva (22103676)
# 9      25/10/2022 23:09   Luís Felipe Mattos da Silva (22103676)
# 10     25/10/2022 23:09   Luís Felipe Mattos da Silva (22103676)
# 11     25/10/2022 23:09   Luís Felipe Mattos da Silva (22103676)
# 12     25/10/2022 23:09   Luís Felipe Mattos da Silva (22103676)
# 13     25/10/2022 23:09   Luís Felipe Mattos da Silva (22103676)
# 14     23/10/2022 12:29   Pedro Otávio Furtado Duarte (22103861)
# 15     19/10/2022 12:41      José Inácio Mota Nazario (22103674)
# 16     19/10/2022 12:34      José Inácio Mota Nazario (22103674)
# 17     19/10/2022 12:34      José Inácio Mota Nazario (22103674)
# 18     19/10/2022 12:33      José Inácio Mota Nazario (22103674)
# 19     19/10/2022 12:33      José Inácio Mota Nazario (22103674)
# 20     18/10/2022 21:50      José Inácio Mota Nazario (22103674)
# 21     18/10/2022 21:50      José Inácio Mota Nazario (22103674)
# 22     18/10/2022 21:48      José Inácio Mota Nazario (22103674)
# 23     17/10/2022 08:29  João Gabriel de Borba Coelho (22103675)
# 24     14/10/2022 14:59       Sophia Silveira Vieceli (22102010)
# 25     14/10/2022 14:58       Sophia Silveira Vieceli (22102010)
# 26     14/10/2022 14:58       Sophia Silveira Vieceli (22102010)
# 27     13/10/2022 16:18               Carolina Dekker (22101993)
# 28      6/10/2022 09:19               Carolina Dekker (22101993)
# 29     26/09/2022 14:14              Fabio Bosa Roque (22101996)
# ...                 ...                                      ...
# 12350  12/04/2022 16:18                        Cristian Cechinel
# 12351  12/04/2022 16:18                        Cristian Cechinel
# 12352  12/04/2022 16:18                        Cristian Cechinel
# 12353  12/04/2022 16:18                        Cristian Cechinel
# 12354  12/04/2022 16:18                        Cristian Cechinel
# 12355  12/04/2022 16:18                        Cristian Cechinel
# 12356  12/04/2022 16:18                        Cristian Cechinel
# 12357  12/04/2022 16:18                        Cristian Cechinel
# 12358  12/04/2022 16:18                        Cristian Cechinel
# 12359  12/04/2022 16:18                        Cristian Cechinel
# 12360  12/04/2022 16:18                        Cristian Cechinel
# 12361  12/04/2022 16:18                        Cristian Cechinel
# 12362  12/04/2022 16:18                        Cristian Cechinel
# 12363  12/04/2022 16:18                        Cristian Cechinel
# 12364  12/04/2022 16:18                        Cristian Cechinel
# 12365  12/04/2022 16:18                        Cristian Cechinel
# 12366  12/04/2022 16:18                        Cristian Cechinel
# 12367  12/04/2022 16:18                        Cristian Cechinel
# 12368  12/04/2022 16:18                        Cristian Cechinel
# 12369  12/04/2022 16:18                        Cristian Cechinel
# 12370  12/04/2022 16:18                        Cristian Cechinel
# 12371  12/04/2022 16:18                        Cristian Cechinel
# 12372  12/04/2022 16:18                        Cristian Cechinel
# 12373  12/04/2022 16:18                        Cristian Cechinel
# 12374  12/04/2022 16:18                        Cristian Cechinel
# 12375  12/04/2022 16:18                        Cristian Cechinel
# 12376  12/04/2022 16:18                        Cristian Cechinel
# 12377  12/04/2022 16:18                        Cristian Cechinel
# 12378  12/04/2022 16:18                        Cristian Cechinel
# 12379  12/04/2022 16:18                        Cristian Cechinel
#
#                                Usuário afetado  \
# 0                                            -
# 1                                            -
# 2                                            -
# 3                                            -
# 4                                            -
# 5                                            -
# 6                                            -
# 7       Luís Felipe Mattos da Silva (22103676)
# 8                                            -
# 9                                            -
# 10                                           -
# 11                                           -
# 12      Luís Felipe Mattos da Silva (22103676)
# 13                                           -
# 14                                           -
# 15         José Inácio Mota Nazario (22103674)
# 16                                           -
# 17                                           -
# 18         José Inácio Mota Nazario (22103674)
# 19                                           -
# 20         José Inácio Mota Nazario (22103674)
# 21                                           -
# 22                                           -
# 23                                           -
# 24                                           -
# 25                                           -
# 26                                           -
# 27                                           -
# 28                                           -
# 29                                           -
# ...                                        ...
# 12350           Arthur José Rabello (22101991)
# 12351           Arthur José Rabello (22101991)
# 12352  Messias dos Santos Rodrigues (21204466)
# 12353  Messias dos Santos Rodrigues (21204466)
# 12354  Gregory Nicolas Soares Berto (20206743)
# 12355  Gregory Nicolas Soares Berto (20206743)
# 12356       Elisabete Pereira Cosmo (20105412)
# 12357       Elisabete Pereira Cosmo (20105412)
# 12358           Everton Cruz Soares (20104573)
# 12359           Everton Cruz Soares (20104573)
# 12360        Vitor Silva Filgueiras (20102039)
# 12361        Vitor Silva Filgueiras (20102039)
# 12362       Marcos de Castro Junior (19207039)
# 12363       Marcos de Castro Junior (19207039)
# 12364       Julia Vanessa Francisco (19204582)
# 12365       Julia Vanessa Francisco (19204582)
# 12366       Felipe da Cunha Germano (19104853)
# 12367       Felipe da Cunha Germano (19104853)
# 12368  Guilherme da Rosa dos Santos (17203200)
# 12369  Guilherme da Rosa dos Santos (17203200)
# 12370                        Cristian Cechinel
# 12371                        Cristian Cechinel
# 12372                                        -
# 12373                                        -
# 12374                                        -
# 12375                                        -
# 12376                                        -
# 12377                                        -
# 12378                                        -
# 12379                                        -
#
#                                       Contexto do Evento  \
# 0      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 1      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 2      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 3      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 4      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 5      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 6      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 7      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 8      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 9      Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 10     Laboratório Virtual de Programação: Verificar ...
# 11     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 13     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 14     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 15     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 16                    Arquivo: Plano de Ensino - 2022-01
# 17                    Arquivo: Plano de Ensino - 2022-01
# 18     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 19     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 20     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 21     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 22     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 23     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 24     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 25                           Livro: Introdução ao Python
# 26     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 27     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 28     Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 29                    Arquivo: Plano de Ensino - 2022-01
# ...                                                  ...
# 12350  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12351  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12352  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12353  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12354  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12355  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12356  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12357  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12358  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12359  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12360  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12361  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12362  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12363  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12364  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12365  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12366  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12367  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12368  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12369  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12370  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12371  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12372  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12373  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12374  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12375  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12376  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12377  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12378  Curso: CIT7580-01652A (20221) - Algoritmos e P...
# 12379  Curso: CIT7580-01652A (20221) - Algoritmos e P...
#
#                                Componente  \
# 0                                    Logs
# 1                                 Sistema
# 2                                 Sistema
# 3                                 Sistema
# 4                                 Sistema
# 5                                 Sistema
# 6                                 Sistema
# 7                    Relatório do usuário
# 8                                 Sistema
# 9                                 Sistema
# 10     Laboratório de Programação Virtual
# 11                                Sistema
# 12                   Relatório do usuário
# 13                                Sistema
# 14                                Sistema
# 15                   Relatório do usuário
# 16                                Arquivo
# 17                                Arquivo
# 18                   Relatório do usuário
# 19                                Sistema
# 20                   Relatório do usuário
# 21                                Sistema
# 22                                Sistema
# 23                                Sistema
# 24                                Sistema
# 25                                  Livro
# 26                                Sistema
# 27                                Sistema
# 28                                Sistema
# 29                                Arquivo
# ...                                   ...
# 12350                             Sistema
# 12351                             Sistema
# 12352                             Sistema
# 12353                             Sistema
# 12354                             Sistema
# 12355                             Sistema
# 12356                             Sistema
# 12357                             Sistema
# 12358                             Sistema
# 12359                             Sistema
# 12360                             Sistema
# 12361                             Sistema
# 12362                             Sistema
# 12363                             Sistema
# 12364                             Sistema
# 12365                             Sistema
# 12366                             Sistema
# 12367                             Sistema
# 12368                             Sistema
# 12369                             Sistema
# 12370                             Sistema
# 12371                             Sistema
# 12372                             Sistema
# 12373                             Sistema
# 12374                             Sistema
# 12375                             Sistema
# 12376                             Sistema
# 12377                             Sistema
# 12378                             Sistema
# 12379                             Sistema
#
#                                   Nome do evento  \
# 0                         Relatório de log visto
# 1                                    Curso visto
# 2                       Lista de usuários vistos
# 3                       Lista de usuários vistos
# 4                                    Curso visto
# 5                                    Curso visto
# 6                                    Curso visto
# 7      Relatório de notas do usuário visualizado
# 8                                    Curso visto
# 9                                    Curso visto
# 10               mod_vpl: vpl description viewed
# 11                                   Curso visto
# 12     Relatório de notas do usuário visualizado
# 13                                   Curso visto
# 14                                   Curso visto
# 15     Relatório de notas do usuário visualizado
# 16                   Módulo do curso visualizado
# 17                   Módulo do curso visualizado
# 18     Relatório de notas do usuário visualizado
# 19                                   Curso visto
# 20     Relatório de notas do usuário visualizado
# 21                                   Curso visto
# 22                                   Curso visto
# 23                                   Curso visto
# 24                                   Curso visto
# 25                   Módulo do curso visualizado
# 26                                   Curso visto
# 27                                   Curso visto
# 28                                   Curso visto
# 29                   Módulo do curso visualizado
# ...                                          ...
# 12350                            Papel atribuído
# 12351                  Usuário inscrito no curso
# 12352                            Papel atribuído
# 12353                  Usuário inscrito no curso
# 12354                            Papel atribuído
# 12355                  Usuário inscrito no curso
# 12356                            Papel atribuído
# 12357                  Usuário inscrito no curso
# 12358                            Papel atribuído
# 12359                  Usuário inscrito no curso
# 12360                            Papel atribuído
# 12361                  Usuário inscrito no curso
# 12362                            Papel atribuído
# 12363                  Usuário inscrito no curso
# 12364                            Papel atribuído
# 12365                  Usuário inscrito no curso
# 12366                            Papel atribuído
# 12367                  Usuário inscrito no curso
# 12368                            Papel atribuído
# 12369                  Usuário inscrito no curso
# 12370                            Papel atribuído
# 12371                  Usuário inscrito no curso
# 12372              Instância de inscrição criada
# 12373              Instância de inscrição criada
# 12374              Instância de inscrição criada
# 12375              Instância de inscrição criada
# 12376                      Seção do curso criada
# 12377                      Seção do curso criada
# 12378                      Seção do curso criada
# 12379                               Curso criado
#
#                                                Descrição Origem  \
# 0      The user with id '169763' viewed the log repor...    web
# 1      The user with id '169763' viewed the course wi...    web
# 2      The user with id '241551' viewed the list of u...    web
# 3      The user with id '241551' viewed the list of u...    web
# 4      The user with id '241551' viewed the course wi...    web
# 5      The user with id '242626' viewed the course wi...    web
# 6      The user with id '241554' viewed the course wi...    web
# 7      The user with id '241553' viewed the user repo...    web
# 8      The user with id '241553' viewed the course wi...    web
# 9      The user with id '241553' viewed the course wi...    web
# 10     The user with id 241553 viewed description of ...    web
# 11     The user with id '241553' viewed the course wi...    web
# 12     The user with id '241553' viewed the user repo...    web
# 13     The user with id '241553' viewed the course wi...    web
# 14     The user with id '242626' viewed the course wi...    web
# 15     The user with id '241551' viewed the user repo...     ws
# 16     The user with id '241551' viewed the 'resource...     ws
# 17     The user with id '241551' viewed the 'resource...     ws
# 18     The user with id '241551' viewed the user repo...     ws
# 19     The user with id '241551' viewed the course wi...     ws
# 20     The user with id '241551' viewed the user repo...    web
# 21     The user with id '241551' viewed the course wi...    web
# 22     The user with id '241551' viewed the course wi...     ws
# 23     The user with id '241552' viewed the course wi...    web
# 24     The user with id '237906' viewed the course wi...    web
# 25     The user with id '237906' viewed the 'book' ac...    web
# 26     The user with id '237906' viewed the course wi...    web
# 27     The user with id '237977' viewed the course wi...    web
# 28     The user with id '237977' viewed the course wi...    web
# 29     The user with id '240140' viewed the 'resource...    web
# ...                                                  ...    ...
# 12350  The user with id '169763' assigned the role wi...    web
# 12351  The user with id '169763' enrolled the user wi...    web
# 12352  The user with id '169763' assigned the role wi...    web
# 12353  The user with id '169763' enrolled the user wi...    web
# 12354  The user with id '169763' assigned the role wi...    web
# 12355  The user with id '169763' enrolled the user wi...    web
# 12356  The user with id '169763' assigned the role wi...    web
# 12357  The user with id '169763' enrolled the user wi...    web
# 12358  The user with id '169763' assigned the role wi...    web
# 12359  The user with id '169763' enrolled the user wi...    web
# 12360  The user with id '169763' assigned the role wi...    web
# 12361  The user with id '169763' enrolled the user wi...    web
# 12362  The user with id '169763' assigned the role wi...    web
# 12363  The user with id '169763' enrolled the user wi...    web
# 12364  The user with id '169763' assigned the role wi...    web
# 12365  The user with id '169763' enrolled the user wi...    web
# 12366  The user with id '169763' assigned the role wi...    web
# 12367  The user with id '169763' enrolled the user wi...    web
# 12368  The user with id '169763' assigned the role wi...    web
# 12369  The user with id '169763' enrolled the user wi...    web
# 12370  The user with id '169763' assigned the role wi...    web
# 12371  The user with id '169763' enrolled the user wi...    web
# 12372  The user with id '169763' created the instance...    web
# 12373  The user with id '169763' created the instance...    web
# 12374  The user with id '169763' created the instance...    web
# 12375  The user with id '169763' created the instance...    web
# 12376  The user with id '169763' created section numb...    web
# 12377  The user with id '169763' created section numb...    web
# 12378  The user with id '169763' created section numb...    web
# 12379  The user with id '169763' created the course w...    web
#
#            endereço IP
# 0      150.162.234.116
# 1      150.162.234.116
# 2       179.108.174.81
# 3       179.108.174.81
# 4       179.108.174.81
# 5      179.124.197.122
# 6       150.162.234.45
# 7          201.76.2.21
# 8          201.76.2.21
# 9          201.76.2.21
# 10         201.76.2.21
# 11         201.76.2.21
# 12         201.76.2.21
# 13         201.76.2.21
# 14     179.124.197.122
# 15      179.108.174.62
# 16      179.108.174.62
# 17      179.108.174.62
# 18      179.108.174.62
# 19      179.108.174.62
# 20     150.162.218.231
# 21     150.162.218.231
# 22     150.162.218.231
# 23      179.124.199.54
# 24       45.162.66.205
# 25       45.162.66.205
# 26       45.162.66.205
# 27      179.108.174.53
# 28     177.174.243.191
# 29         201.76.2.10
# ...                ...
# 12350    143.255.96.22
# 12351    143.255.96.22
# 12352    143.255.96.22
# 12353    143.255.96.22
# 12354    143.255.96.22
# 12355    143.255.96.22
# 12356    143.255.96.22
# 12357    143.255.96.22
# 12358    143.255.96.22
# 12359    143.255.96.22
# 12360    143.255.96.22
# 12361    143.255.96.22
# 12362    143.255.96.22
# 12363    143.255.96.22
# 12364    143.255.96.22
# 12365    143.255.96.22
# 12366    143.255.96.22
# 12367    143.255.96.22
# 12368    143.255.96.22
# 12369    143.255.96.22
# 12370    143.255.96.22
# 12371    143.255.96.22
# 12372    143.255.96.22
# 12373    143.255.96.22
# 12374    143.255.96.22
# 12375    143.255.96.22
# 12376    143.255.96.22
# 12377    143.255.96.22
# 12378    143.255.96.22
# 12379    143.255.96.22
#
# [12380 rows x 9 columns]

# %%
#Colunas, Linhas e Mais

#ler os topicos
#df.columns

#ler cada coluna
#print(df[['Name', 'Type 1']][0:5])

#ler cada linha
#print(df.iloc[1])
#for index, row in df.iterrows():
    #print(index, row)
#df.loc[df['Nome completo'] == 'Joel João Medeiros Filho (17103359)']


#ler uma (linha/Coluna) Especifica
#print(df.iloc[2,1])

# %%
#Posicionando e Descrevendo Dados

#Descrição dos dados
#df.describe()


#posicionando os valores de acordo com ordem alfabetica do tipo e numeração do HP (do menor pro maior)
#df.sort_values(['Type 1',"HP"], ascending=[True,True])

# %%
#Fazendo mudanças nos dados

#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#df = df.drop(columns=["Total"])

#df['Total'] = df.iloc[:, 4:10].sum(axis=1)

#cols = list(df.columns)
#df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

#df.head(5)

# %%
#Fazendo o Data Frame virar uma nova File

#df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

#df.to_csv('modified.txt',index=False, sep='\t')

# %%
df.loc[(df['Nome Completo'] == 'Cristian Cechinel') | (df['Contexto do Evento
'] == [('Curso: CIT7580-01652A (20221) - Algoritmos e Programação')]

#new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

#new_df.to_csv('filtered.csv')

#new_df.reset_index(drop=True, inplace=True)

#new_df
# Out:
#   File "<ipython-input-18-06f7f74d827f>", line 1
#     df.loc[(df['Nome Completo'] == 'Cristian Cechinel') | (df['Contexto do Evento
#                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
import re


#df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I, regex=True)] 
#^ = ele procura apenas o que começa com o que vem depois

#df.loc[~df['Name'].str.contains('Mega')]
#~ = a função ! de NOT se tirar o ~ aparece apenas os pokemons MEGA

# %%
#df.loc[df["Type 1"] == "Flamer", 'Type 1'] = 'Fire'

#df

# %%
#df = pd.read_csv('modified.csv')

#df['count'] = 1

#df.groupby(['Type 1','Type 2']).count()['count']



#df.groupby(['Type 1']).sum()

#df.groupby(['Type 1']).mean()

#df.groupby(['Type 1']).count()
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
#                       ..
# Rock      Fighting     1
#           Flying       4
#           Grass        2
#           Ground       6
#           Ice          2
#           Psychic      2
#           Steel        3
#           Water        6
# Steel     Dragon       1
#           Fairy        3
#           Fighting     1
#           Flying       1
#           Ghost        4
#           Ground       2
#           Psychic      7
#           Rock         3
# Water     Dark         6
#           Dragon       2
#           Electric     2
#           Fairy        2
#           Fighting     3
#           Flying       7
#           Ghost        2
#           Grass        3
#           Ground      10
#           Ice          3
#           Poison       3
#           Psychic      5
#           Rock         4
#           Steel        1
# Name: count, Length: 136, dtype: int64
